# %% [markdown]
# ### Q4. Can you tell me about your internship?
#
# I completed a two-month internship as a Data Science Intern at Digital Ipsum Pvt. Ltd.
#
# During my internship, I worked on a project called MindSense AI. It is a machine learning-based mental health risk prediction application.
#
# My main work was on data preprocessing, feature engineering, model training and evaluation. I used Logistic Regression for risk classification and also integrated SHAP for Explainable AI, so that we could understand why the model was making a particular prediction.
#
# I also worked on application features like risk assessment, analytics, recommendations, PDF reports and assessment history.
#
# Apart from this, I worked on some data-processing tasks such as filtering data, removing duplicates, reverse ranking, and validating active email addresses.
#
# Overall, this internship gave me practical experience in building an end-to-end application and understanding how different components work together.
#
#
#
#
# Remember the internship in 6 points
#
# - Company: Digital Ipsum Pvt. Ltd.
#
# - Role: Data Science Intern
#
# - Project: MindSense AI
#
# - ML work: preprocessing → feature engineering → training → evaluation
#
# - Application work: SHAP → analytics → recommendations → PDF → history
#
# - Other tasks: filtering → duplicate removal → reverse ranking → active email validation

# %% [markdown]
# ### Q5. What was your role and responsibility during the internship?
#
# My role was Data Science Intern. My responsibilities were mainly related to data processing and machine learning application development.
#
# I worked on MindSense AI, where I worked on data preprocessing, feature engineering, model training and evaluation, and SHAP-based Explainable AI.
#
# I also worked with another team on a Filtering and Reverse Ranking project. In that work, I helped identify and remove duplicate data, developed a reverse ranking mechanism based on relevance, and created a script to validate and filter active email addresses.
#
# So overall, my responsibilities included data cleaning, data processing, building data-related solutions, and contributing to the development of the machine learning application.

# %% [markdown]
# # Step 3 — Internship
#
# ## Question 3: “What exactly did you work on during your internship?”
#
# ### Answer:
#
# “During my internship, I worked mainly on two areas.
#
# First, I worked on MindSense AI, a machine learning-based risk prediction application. I worked on data preprocessing, feature engineering, model training and evaluation. I also integrated SHAP for Explainable AI, so we could understand the important features behind the model’s prediction. I also contributed to features like risk assessment, analytics, recommendations, PDF reports and assessment history.
#
# Second, I collaborated with another team on a Filtering and Reverse Ranking project. I worked on removing duplicate records, creating a reverse ranking mechanism based on relevance, and validating and filtering active email addresses.
#
# So, my internship gave me experience in both machine learning application development and practical data-processing tasks.”
#
# ### Easy way to remember:
#
# **MindSense AI**
# - Data preprocessing
# - Feature engineering
# - Model training and evaluation
# - SHAP / Explainable AI
# - Risk assessment
# - Analytics
# - Recommendations
# - PDF reports
# - Assessment history
#
# **Other team project**
# - Filtering
# - Duplicate removal
# - Reverse ranking
# - Active email validation
#
# ### Interview Tip:
#
# This answer should take around **60–75 seconds**.
#
# Do not explain every technical detail here. Give the overview first.
#
# If the interviewer wants more details, they may ask:
#
# **“Can you explain your MindSense AI project in detail?”**
#
# Then we will explain the project separately.
